# %% [markdown]
# #### Imports

# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %% [markdown]
# #### Read csv

# %%
flats = pd.read_csv('../database.csv',sep=',',dtype='unicode')

# %% [markdown]
# **Convert strings to numeric**

# %%
flats = flats.apply(pd.to_numeric, errors='ignore')

# %% [markdown]
# ### Prepare dataframe for visualising

# %% [markdown]
# **Create a dataframe with addresses**

# %%
addresses_df = flats['address'].str.replace("[","").str.replace(" ","").str.replace("]","").str.replace('"',"").str.split(",",expand=True)
for addr in list(addresses_df):
    addresses_df = addresses_df.rename(columns={addr : 'addr_'+str(addr) })

# %% [markdown]
# **Choose flats that have location, price and area**

# %%
flats_info = flats.loc[(flats.latitude.notna()) & (flats.total_price.notna()) & (flats.total_area.notna())]

# %% [markdown]
# **Choose flats from [city]**

# %%
city = 'Москва'

# %%
flats_info_city = flats_info.loc[addresses_df.iloc[:, 0] == city]
flats_info_city = flats_info_city[['Number_of_rooms', 'total_price', 'total_area', 'latitude' , 'longitude']]
flats_info_city = pd.concat([flats_info_city, addresses_df], axis=1, join='inner')

# %% [markdown]
# #### Choose only those districts, that have more than 5 ads in it.
# We need it to exclude flats with incorrect names

# %%
districts_city = flats_info_city.groupby('addr_1')
districts_city_count = flats_info_city.groupby('addr_1')['addr_0'].count()
districts_city_count = districts_city_count.loc[flats_info_city.groupby('addr_1')['addr_0'].count() > 20]
flats_info_city = flats_info_city.loc[flats_info_city.addr_1.isin(districts_city_count.index)]

# %% [markdown]
# #### Visualize location of ads

# %%
px.set_mapbox_access_token('pk.eyJ1Ijoibmlrc29iOTciLCJhIjoiY2s4cGs3NzRnMDAxODNnbnR0M3QxNHl5NyJ9.Ppwf_rp0v7AP5-VepAWydw')

fig = px.scatter_mapbox(flats_info_city, lat="latitude", lon="longitude", color='addr_1', size_max=15, zoom=10)
fig.show()
# Out:
# <div>
#
#
#             <div id="c3fc0328-7104-4cad-b3e7-bade3e44a9ca" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c3fc0328-7104-4cad-b3e7-bade3e44a9ca")) {
#                     Plotly.newPlot(
#                         'c3fc0328-7104-4cad-b3e7-bade3e44a9ca',
#                         [{"hovertemplate": "addr_1=\u0412\u0410\u041e<br>latitude=%{lat}<br>longitude=%{lon}<extra></extra>", "lat": [55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.789792799999994, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.74711679999999, 55.9290838, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.8165071, 55.7368282, 55.602857400000005, 55.77376795, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.745930099999995, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.8165071, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.8165071, 55.73877985, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.731418500000004, 55.602857400000005, 55.602857400000005, 55.74688925, 55.74245795, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.73877985, 55.75753625, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.794360600000005, 55.81130600000001, 55.81130600000001, 55.81130600000001, 55.81130600000001, 55.81130600000001, 55.81130600000001, 55.81130600000001, 55.81130600000001, 55.81130600000001, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.7958865, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.8008807, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.8077606, 55.602857400000005, 55.7976625, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.82304695000001, 55.7231147, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.73402585, 55.8225463, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.602857400000005, 55.60285740000 ...

# %% [markdown]
# #### Visualize number of ads in districts
#     Find median value for a district.
#     Count number of ads in it.
#     Draw circle of corresponding size

# %%
districts_city.median()
districts_city_new = pd.concat([districts_city.median(), districts_city_count.to_frame('count')], axis=1, join='inner')

# %%
px.set_mapbox_access_token('pk.eyJ1Ijoibmlrc29iOTciLCJhIjoiY2s4cGs3NzRnMDAxODNnbnR0M3QxNHl5NyJ9.Ppwf_rp0v7AP5-VepAWydw')

fig = px.scatter_mapbox(districts_city_new, lat="latitude", lon="longitude", size='count', size_max=100, color=districts_city_new.index, zoom=10)
fig.show()
# Out:
# <div>
#
#
#             <div id="f06a0d46-523d-4d95-8110-ca620cb4b4a2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f06a0d46-523d-4d95-8110-ca620cb4b4a2")) {
#                     Plotly.newPlot(
#                         'f06a0d46-523d-4d95-8110-ca620cb4b4a2',
#                         [{"hovertemplate": "color=10-\u044f\u041f\u0430\u0440\u043a\u043e\u0432\u0430\u044f<br>count=%{marker.size}<br>latitude=%{lat}<br>longitude=%{lon}<extra></extra>", "lat": [55.602857400000005], "legendgroup": "10-\u044f\u041f\u0430\u0440\u043a\u043e\u0432\u0430\u044f", "lon": [37.2804403], "marker": {"color": "#636efa", "size": [16], "sizemode": "area", "sizeref": 0.4068}, "mode": "markers", "name": "10-\u044f\u041f\u0430\u0440\u043a\u043e\u0432\u0430\u044f", "showlegend": true, "subplot": "mapbox", "type": "scattermapbox"}, {"hovertemplate": "color=\u0411\u0435\u043b\u043e\u0440\u0435\u0447\u0435\u043d\u0441\u043a\u0430\u044f<br>count=%{marker.size}<br>latitude=%{lat}<br>longitude=%{lon}<extra></extra>", "lat": [55.67160595], "legendgroup": "\u0411\u0435\u043b\u043e\u0440\u0435\u0447\u0435\u043d\u0441\u043a\u0430\u044f", "lon": [37.765518751197284], "marker": {"color": "#EF553B", "size": [5], "sizemode": "area", "sizeref": 0.4068}, "mode": "markers", "name": "\u0411\u0435\u043b\u043e\u0440\u0435\u0447\u0435\u043d\u0441\u043a\u0430\u044f", "showlegend": true, "subplot": "mapbox", "type": "scattermapbox"}, {"hovertemplate": "color=\u0412\u0410\u041e<br>count=%{marker.size}<br>latitude=%{lat}<br>longitude=%{lon}<extra></extra>", "lat": [55.602857400000005], "legendgroup": "\u0412\u0410\u041e", "lon": [37.2804403], "marker": {"color": "#00cc96", "size": [4068], "sizemode": "area", "sizeref": 0.4068}, "mode": "markers", "name": "\u0412\u0410\u041e", "showlegend": true, "subplot": "mapbox", "type": "scattermapbox"}, {"hovertemplate": "color=\u0412\u0435\u0440\u043d\u0430\u0434\u0441\u043a\u043e\u0433\u043e<br>count=%{marker.size}<br>latitude=%{lat}<br>longitude=%{lon}<extra></extra>", "lat": [55.6528128], "legendgroup": "\u0412\u0435\u0440\u043d\u0430\u0434\u0441\u043a\u043e\u0433\u043e", "lon": [37.4758709], "marker": {"color": "#ab63fa", "size": [2], "sizemode": "area", "sizeref": 0.4068}, "mode": "markers", "name": "\u0412\u0435\u0440\u043d\u0430\u0434\u0441\u043a\u043e\u0433\u043e", "showlegend": true, "subplot": "mapbox", "type": "scattermapbox"}, {"hovertemplate": "color=\u0412\u043e\u043b\u0436\u0441\u043a\u0438\u0439\u0431<br>count=%{marker.size}<br>latitude=%{lat}<br>longitude=%{lon}<extra></extra>", "lat": [48.78290505], "legendgroup": "\u0412\u043e\u043b\u0436\u0441\u043a\u0438\u0439\u0431", "lon": [44.76544162811556], "marker": {"color": "#FFA15A", "size": [2], "sizemode": "area", "sizeref": 0.4068}, "mode": "markers", "name": "\u0412\u043e\u043b\u0436\u0441\u043a\u0438\u0439\u0431", "showlegend": true, "subplot": "mapbox", "type": "scattermapbox"}, {"hovertemplate": "color=\u0417\u0410\u041e<br>count=%{marker.size}<br>latitude=%{lat}<br>longitude=%{lon}<extra></extra>", "lat": [55.7138916], "legendgroup": "\u0417\u0410\u041e", "lon": [37.466435056280034], "marker": {"color": "#19d3f3", "size": [801], "sizemode": "area", "sizeref": 0.4068}, "mode": "markers", "name": "\u0417\u0410\u041e", "showlegend": true, "subplot": "mapbox", "type": "scattermapbox"}, {"hovertemplate": "color=\u0417\u0430\u0449\u0438\u0442\u043d\u0438\u043a\u043e\u0432\u041c\u043e\u0441\u043a\u0432\u044b<br>count=%{marker.size}<br>latitude=%{lat}<br>longitude=%{lon}<extra></extra>", "lat": [55.702940825], "legendgroup": "\u0417\u0430\u0449\u0438\u0442\u043d\u0438\u043a\u043e\u0432\u041c\u043e\u0441\u043a\u0432\u044b", "lon": [37.9246895405282], "marker": {"color": "#FF6692", "size": [2], "sizemode": "area", "sizeref": 0.4068}, "mode": "markers", "name": "\u0417\u0430\u0449\u0438\u0442\u043d\u0438\u043a\u043e\u0432\u041c\u043e\u0441\u043a\u0432\u044b", "showlegend": true, "subplot": "mapbox", "type": "scattermapbox"}, {"hovertemplate": "color=\u0417\u0435\u043b\u0410\u041e<br>count=%{marker.size}<br>latitude=%{lat}<br>longitude=%{lon}<extra></extra>", "lat": [55.9664759], "legendgroup": "\u0417\u0435\u043b\u0410\u041e", "lon": [37.150006023389956], "marker": {"color": "#B6E880", "size": [11], "sizemode": "area", "sizeref": 0.406 ...

# %% [markdown]
# #### Info about city

# %%
print( 'Number of ads in ', city, ' :', flats_info_city.addr_0.count())
print( 'Number of districts in ', city, ' :', len(districts_city_count))
# Out:
# Number of ads in  Москва  : 10171
# Number of districts in  Москва  : 25
